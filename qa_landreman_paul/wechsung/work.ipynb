# %%
from simsopt._core import load
from simsopt.geo import CurveXYZFourier, SurfaceRZFourier
from simsopt.field import BiotSavart, Coil, load_coils_from_makegrid_file
import matplotlib.pyplot as plt

# %matplotlib widget

# %%
order = 16
quandidates = [
    'output_well_True_lengthbound_24.0_kap_5.0_msc_5.0_dist_0.1_fil_0_ig_6_order_16_alstart_0_expquad_samples_4096_sigma_0.001_usedetig.nc',
    'output_well_True_lengthbound_24.0_kap_5.0_msc_5.0_dist_0.1_fil_0_ig_5_order_16_alstart_0_expquad.nc',
    'output_well_True_lengthbound_22.0_kap_5.0_msc_5.0_dist_0.1_fil_0_ig_7_order_16_alstart_0_expquad.nc',
    'output_well_True_lengthbound_22.0_kap_5.0_msc_5.0_dist_0.1_fil_0_ig_6_order_16_alstart_0_expquad_samples_4096_sigma_0.001_usedetig.nc',
    'output_well_True_lengthbound_20.0_kap_5.0_msc_5.0_dist_0.1_fil_0_ig_3_order_16_alstart_0_expquad.nc',
    'output_well_False_lengthbound_18.0_kap_5.0_msc_5.0_dist_0.1_fil_0_ig_6_order_16_alstart_0_expquad_samples_4096_sigma_0.001_usedetig.nc',
    'output_well_False_lengthbound_18.0_kap_5.0_msc_5.0_dist_0.1_fil_0_ig_3_order_16_alstart_0_expquad.nc'
]
for fname in quandidates:
    coils = load_coils_from_makegrid_file( fname, order )
    
    for ii, c in enumerate(coils):
        sgn = 1
        if ii>3 and ii<8:
            sgn = -1
        if ii>11:
            sgn = -1
        cur = c.current.get_value()
        c.current.set('x0', sgn*cur*1E7)
    
    for ii, c in enumerate(coils):
        curve = c.curve
        curve.x = curve.x * 9.229649839967937

    bs = BiotSavart(coils)
    surf = SurfaceRZFourier.from_wout('../wout_landreman_paul_qa_scaled.nc')
    bs.set_points(surf.gamma().reshape((-1,3)))

    ss = surf.gamma().shape
    theta = surf.quadpoints_theta * 2 * np.pi
    phi = surf.quadpoints_phi * 2 * np.pi
    fig, ax = plt.subplots()
    Bdotn = np.sum(bs.B().reshape(ss) * surf.unitnormal(), axis=2) 
    ax.set_ylabel(r'$\phi$')
    ax.set_xlabel(r'$\theta$')
    c = ax.contourf(theta,phi,Bdotn)
    plt.colorbar(c,label=r'$B\cdot n$')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from simsopt.field import apply_symmetries_to_curves, apply_symmetries_to_currents, Coil

fname = quandidates[-1]
coils = load_coils_from_makegrid_file( fname, order )

ncoils = len(coils)
base_coils = coils[0:int(ncoils/4)]
base_curves = [c.curve for c in base_coils]
base_currents = [c.current for c in base_coils]

nfp = surf.nfp

for ii, c in enumerate(base_currents):
    sgn = 1
    if ii>3 and ii<8:
        sgn = -1
    if ii>11:
        sgn = -1
    cur = c.get_value()
    c.set('x0', sgn*cur*1E7)

for ii, c in enumerate(base_curves):
    c.x = c.x * 9.229649839967937

curves = apply_symmetries_to_curves( base_curves, nfp, True )
currents = apply_symmetries_to_currents( base_currents, nfp, True )
coils = [Coil(curve, current) for curve, current in zip(curves, currents)]

bs = BiotSavart(coils)
surf = SurfaceRZFourier.from_wout('../wout_landreman_paul_qa_scaled.nc')
bs.set_points(surf.gamma().reshape((-1,3)))

ss = surf.gamma().shape
theta = surf.quadpoints_theta * 2 * np.pi
phi = surf.quadpoints_phi * 2 * np.pi
fig, ax = plt.subplots()
Bdotn = np.sum(bs.B().reshape(ss) * surf.unitnormal(), axis=2) 
ax.set_ylabel(r'$\phi$')
ax.set_xlabel(r'$\theta$')
c = ax.contourf(theta,phi,Bdotn)
plt.colorbar(c,label=r'$B\cdot n$')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig = plt.figure()
ax = fig.add_subplot(projection='3d')
surf.plot(ax=ax, show=False, close=True)
for c in coils:
    c.plot(ax=ax, show=False)

ax.set_aspect('equal')
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
bs.save('wechsung_coils.json')
# Out:
# '{\n  "@module": "simsopt._core.json",\n  "@class": "SIMSON",\n  "@version": "0.19.0.post0+gc859dfb3.d20230815.dirty",\n  "graph": {\n    "$type": "ref",\n    "value": "BiotSavart38"\n  },\n  "simsopt_objs": {\n    "11193044800": {\n      "@module": "simsopt._core.optimizable",\n      "@class": "DOFs",\n      "@name": "11193044800",\n      "@version": "0.19.0.post0+gc859dfb3.d20230815.dirty",\n      "x": {\n        "@module": "numpy",\n        "@class": "array",\n        "dtype": "float64",\n        "data": [\n          11.906138072383674,\n          -0.3698872826075361,\n          5.214298854567364,\n          -0.11312009568021889,\n          0.723561797730379,\n          -0.003735207607762481,\n          -0.4399889163022786,\n          -0.013603600770931376,\n          0.052247507014307505,\n          -0.04138406334839013,\n          0.029613694221157998,\n          0.07934516497818789,\n          0.005644822470412036,\n          -0.05826747318347724,\n          -0.0028323345297983863,\n          0.017783455472359173,\n          -0.00047068186367100345,\n          0.0065025476968626405,\n          0.001215704341210983,\n          -0.015345054525798625,\n          0.004109051020423448,\n          0.011827202308149973,\n          -0.007242794274462851,\n          -0.008791597702368448,\n          0.009842180721340592,\n          0.0036739724748742456,\n          -0.008198750569666437,\n          -0.00223413825281651,\n          0.006810500435851374,\n          -0.00032157634189664783,\n          -0.004203172322695311,\n          0.0002311526598271128,\n          0.002154736153101826,\n          2.147119464137527,\n          -1.4368962865778052,\n          1.370187961936139,\n          0.8804776493650615,\n          -0.4620733825465793,\n          -0.549724919640768,\n          0.2796407704381903,\n          0.029801654382256657,\n          0.0020077190067592093,\n          0.07385742337336176,\n          -0.1619407256031883,\n          -0.029465612516722302,\n          0.06623360524484065,\n          -0.010978418785334669,\n          -0.022660690375802026,\n          0.006216444400363092,\n          0.0052678147632173105,\n          -0.00097820250714899,\n          0.002201961598612178,\n          -0.008616637347263558,\n          -0.007382739048488361,\n          0.009852147393829166,\n          0.008009128868309954,\n          -0.012050417627275049,\n          -0.006832751428859865,\n          0.008027640321881656,\n          0.0034406201495341343,\n          -0.007040246264521121,\n          -0.0017361507361736519,\n          0.003033495896771434,\n          -8.71090458980772e-05,\n          -0.0024639990195640853,\n          1.4160872199354925e-05,\n          0.6241290634049486,\n          7.142543840424598,\n          -0.2037525396238325,\n          0.37181423768845473,\n          -0.009474131340597183,\n          -0.3137499312338959,\n          0.1588420606532277,\n          0.04843807145962004,\n          -0.03394689835384335,\n          0.02870799295537348,\n          -0.003932918092032273,\n          0.02494147869861774,\n          0.016283812736689118,\n          -0.0005151735951631313,\n          -0.019091853086831048,\n          0.017238640947833665,\n          0.01521425428312887,\n          0.00918097980751508,\n          -0.0033462399926089985,\n          0.00466665073566071,\n          0.0005849931776230494,\n          0.013746493135935605,\n          0.004805201362071381,\n          0.0013374423989730147,\n          -0.00033626879376776037,\n          0.011289826616461801,\n          0.002476563128941864,\n          0.0020002907711354754,\n          0.0014800103172970874,\n          0.008064154460344402,\n          0.001660644817320757,\n          0.0033094389136853314,\n          0.0019097041851965312\n        ]\n      },\n      "names": [\n        "xc(0)",\n        "xs(1)",\n        "xc(1)",\n        "xs(2)",\n        "xc(2)",\n        "xs(3)",\n        "xc(3)",\n        "xs(4)",\n        "xc(4)",\n        " ...

# %%
for ii, c in enumerate(coils):
    print(ii)
    c.curve.unfix('xc(0)')
# Out:
# 0
# 1
# 2
# 3
# 4
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[154], line 3
#       1 for ii, c in enumerate(coils):
#       2     print(ii)
# ----> 3     c.curve.unfix('xc(0)')
#
# File ~/Github/simsopt/src/simsopt/_core/optimizable.py:1440, in Optimizable.unfix(self, key)
#    1433 def unfix(self, key: Key) -> None:
#    1434     """
#    1435     Unset the fixed attribute for the given degree of freedom
#    1436
#    1437     Args:
#    1438         key: DOF identifier
#    1439     """
# -> 1440     self._dofs.unfix(key)
#    1441     self.update_free_dof_size_indices()
#
# File ~/Github/simsopt/src/simsopt/_core/optimizable.py:200, in DOFs.unfix(self, key)
#     193 """
#     194 Unfixes the specified DOF
#     195
#     196 Args:
#     197     key: Key to identify the DOF
#     198 """
#     199 if isinstance(key, str):
# --> 200     key = self._names.index(key)
#     201 self._free[key] = True
#     202 self._update_opt_indices()
#
# ValueError: 'xc(0)' is not in list

# %%
coils[4].dof_names
# Out:
# ['Current657:x0',
#  'CurveXYZFourier661:xc(0)',
#  'CurveXYZFourier661:xs(1)',
#  'CurveXYZFourier661:xc(1)',
#  'CurveXYZFourier661:xs(2)',
#  'CurveXYZFourier661:xc(2)',
#  'CurveXYZFourier661:xs(3)',
#  'CurveXYZFourier661:xc(3)',
#  'CurveXYZFourier661:xs(4)',
#  'CurveXYZFourier661:xc(4)',
#  'CurveXYZFourier661:xs(5)',
#  'CurveXYZFourier661:xc(5)',
#  'CurveXYZFourier661:xs(6)',
#  'CurveXYZFourier661:xc(6)',
#  'CurveXYZFourier661:xs(7)',
#  'CurveXYZFourier661:xc(7)',
#  'CurveXYZFourier661:xs(8)',
#  'CurveXYZFourier661:xc(8)',
#  'CurveXYZFourier661:xs(9)',
#  'CurveXYZFourier661:xc(9)',
#  'CurveXYZFourier661:xs(10)',
#  'CurveXYZFourier661:xc(10)',
#  'CurveXYZFourier661:xs(11)',
#  'CurveXYZFourier661:xc(11)',
#  'CurveXYZFourier661:xs(12)',
#  'CurveXYZFourier661:xc(12)',
#  'CurveXYZFourier661:xs(13)',
#  'CurveXYZFourier661:xc(13)',
#  'CurveXYZFourier661:xs(14)',
#  'CurveXYZFourier661:xc(14)',
#  'CurveXYZFourier661:xs(15)',
#  'CurveXYZFourier661:xc(15)',
#  'CurveXYZFourier661:xs(16)',
#  'CurveXYZFourier661:xc(16)',
#  'CurveXYZFourier661:yc(0)',
#  'CurveXYZFourier661:ys(1)',
#  'CurveXYZFourier661:yc(1)',
#  'CurveXYZFourier661:ys(2)',
#  'CurveXYZFourier661:yc(2)',
#  'CurveXYZFourier661:ys(3)',
#  'CurveXYZFourier661:yc(3)',
#  'CurveXYZFourier661:ys(4)',
#  'CurveXYZFourier661:yc(4)',
#  'CurveXYZFourier661:ys(5)',
#  'CurveXYZFourier661:yc(5)',
#  'CurveXYZFourier661:ys(6)',
#  'CurveXYZFourier661:yc(6)',
#  'CurveXYZFourier661:ys(7)',
#  'CurveXYZFourier661:yc(7)',
#  'CurveXYZFourier661:ys(8)',
#  'CurveXYZFourier661:yc(8)',
#  'CurveXYZFourier661:ys(9)',
#  'CurveXYZFourier661:yc(9)',
#  'CurveXYZFourier661:ys(10)',
#  'CurveXYZFourier661:yc(10)',
#  'CurveXYZFourier661:ys(11)',
#  'CurveXYZFourier661:yc(11)',
#  'CurveXYZFourier661:ys(12)',
#  'CurveXYZFourier661:yc(12)',
#  'CurveXYZFourier661:ys(13)',
#  'CurveXYZFourier661:yc(13)',
#  'CurveXYZFourier661:ys(14)',
#  'CurveXYZFourier661:yc(14)',
#  'CurveXYZFourier661:ys(15)',
#  'CurveXYZFourier661:yc(15)',
#  'CurveXYZFourier661:ys(16)',
#  'CurveXYZFourier661:yc(16)',
#  'CurveXYZFourier661:zc(0)',
#  'CurveXYZFourier661:zs(1)',
#  'CurveXYZFourier661:zc(1)',
#  'CurveXYZFourier661:zs(2)',
#  'CurveXYZFourier661:zc(2)',
#  'CurveXYZFourier661:zs(3)',
#  'CurveXYZFourier661:zc(3)',
#  'CurveXYZFourier661:zs(4)',
#  'CurveXYZFourier661:zc(4)',
#  'CurveXYZFourier661:zs(5)',
#  'CurveXYZFourier661:zc(5)',
#  'CurveXYZFourier661:zs(6)',
#  'CurveXYZFourier661:zc(6)',
#  'CurveXYZFourier661:zs(7)',
#  'CurveXYZFourier661:zc(7)',
#  'CurveXYZFourier661:zs(8)',
#  'CurveXYZFourier661:zc(8)',
#  'CurveXYZFourier661:zs(9)',
#  'CurveXYZFourier661:zc(9)',
#  'CurveXYZFourier661:zs(10)',
#  'CurveXYZFourier661:zc(10)',
#  'CurveXYZFourier661:zs(11)',
#  'CurveXYZFourier661:zc(11)',
#  'CurveXYZFourier661:zs(12)',
#  'CurveXYZFourier661:zc(12)',
#  'CurveXYZFourier661:zs(13)',
#  'CurveXYZFourier661:zc(13)',
#  'CurveXYZFourier661:zs(14)',
#  'CurveXYZFourier661:zc(14)',
#  'CurveXYZFourier661:zs(15)',
#  'CurveXYZFourier661:zc(15)',
#  'CurveXYZFourier661:zs(16)',
#  'CurveXYZFourier661:zc(16)']

# %%
fname
# Out:
# 'output_well_False_lengthbound_18.0_kap_5.0_msc_5.0_dist_0.1_fil_0_ig_3_order_16_alstart_0_expquad.nc'

# %%
from simsopt.geo import CurveLength

# %%
L = [CurveLength( c.curve ) for c in coils[0:4]]

# %%
sum([ll.J() for ll in L])
# Out:
# Array(166.22514157, dtype=float64)

# %%
coils[0].curve.plot()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# <Axes3D: >

# %%
18*9.229649839967937 /4
# Out:
# 41.533424279855716
